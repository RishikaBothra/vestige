# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(len(df))
width=0.4

fig,ax1=plt.subplots(figsize=(12,5))

# population (left axis)
ax1.bar(x-width/2,df["population"],width,label="population",color="steelblue")
ax1.set_ylabel("population")

# enrolments (right axis)
ax2=ax1.twinx()
ax2.bar(x+width/2,df["enrolments"],width,label="aadhaar enrolments",color="orange")
ax2.set_ylabel("aadhaar enrolments")

# x-axis
ax1.set_xticks(x)
ax1.set_xticklabels(df["state"],rotation=90)
ax1.set_xlabel("state")

# title
plt.title("population vs aadhaar enrolments (state-wise)")

# legends
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.tight_layout()
plt.show()
